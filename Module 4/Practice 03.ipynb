# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl' #inserindo a url em uma variável
r = requests.get(url)

# %%
data_json = r.json()
df = pd.DataFrame(data_json['items'])
df
# Out:
#       id_pleito tipo_interessado          interessado  cod_ibge  uf  \
# 0         64614        Município           Pradópolis   3540903  SP
# 1         45649        Município  Santa Rosa da Serra   3159704  MG
# 2         45294        Município    Bom Retiro do Sul   4302402  RS
# 3         45298        Município            Lindoeste   4113452  PR
# 4         45301        Município           Campo Belo   3111200  MG
# ...         ...              ...                  ...       ...  ..
# 4995       6890        Município        Santos Dumont   3160702  MG
# 4996       6900        Município             Sorocaba   3552205  SP
# 4997       6905        Município             Ipecaetá   2913804  BA
# 4998       6916        Município             Andradas   3102605  MG
# 4999       6919        Município              Vitória   3205309  ES
#
#                    num_pvl             status          num_processo  \
# 0     PVL02.001724/2023-55  Deferido (PVL-IF)                  None
# 1     PVL02.001801/2021-13  Deferido (PVL-IF)                  None
# 2     PVL02.001027/2021-32           Deferido  17944.102367/2021-42
# 3     PVL02.001482/2021-38  Deferido (PVL-IF)                  None
# 4     PVL02.001484/2021-27  Deferido (PVL-IF)                  None
# ...                    ...                ...                   ...
# 4995                  None           Deferido  17944.000453/2014-92
# 4996                  None           Deferido  17944.000455/2012-10
# 4997                  None           Deferido  17944.000456/2011-83
# 4998                  None          Arquivado  17944.000458/2009-58
# 4999                  None           Deferido  17944.000458/2014-15
#
#             data_protocolo                tipo_operacao  \
# 0                     None  Operação contratual interna
# 1                     None  Operação contratual interna
# 2     2021-07-28T19:58:20Z  Operação contratual interna
# 3                     None  Operação contratual interna
# 4                     None  Operação contratual interna
# ...                    ...                          ...
# 4995  2014-03-27T03:00:00Z  Operação contratual interna
# 4996  2012-03-30T03:00:00Z  Operação contratual interna
# 4997  2011-05-03T03:00:00Z  Operação contratual interna
# 4998  2010-03-30T03:00:00Z  Operação contratual interna
# 4999  2014-03-25T03:00:00Z  Operação contratual interna
#
#                                           finalidade  \
# 0     Aquisição de máquinas, equipamentos e veículos
# 1                                     Infraestrutura
# 2                                     Infraestrutura
# 3                                     Infraestrutura
# 4                                     Infraestrutura
# ...                                              ...
# 4995                                  Infraestrutura
# 4996                                  Infraestrutura
# 4997  Aquisição de máquinas, equipamentos e veículos
# 4998                                         Provias
# 4999                             PAC - Contrapartida
#
#                           tipo_credor  \
# 0     Instituição Financeira Nacional
# 1     Instituição Financeira Nacional
# 2     Instituição Financeira Nacional
# 3     Instituição Financeira Nacional
# 4     Instituição Financeira Nacional
# ...                               ...
# 4995  Instituição Financeira Nacional
# 4996  Instituição Financeira Nacional
# 4997  Instituição Financeira Nacional
# 4998  Instituição Financeira Nacional
# 4999  Instituição Financeira Nacional
#
#                                             credor moeda        valor  \
# 0        Agência de Fomento do Estado de São Paulo  Real   2400000.00
# 1                          Caixa Econômica Federal  Real   1300000.00
# 2                          Caixa Econômica Federal  Real   5600000.00
# 3                 Agência de Fomento do Paraná S/A  Real   3050000.00
# 4     Banco de Desenvolvimento de Minas Gerais S/A  Real   3000000.00
# ...                                            ...   ...          ...
# 4995  Banco de Desenvolvimento de Minas Gerais S/A  Real   3000000.00
# 4996     Agência de Fomento do Estado de São Paulo  Real   3000000.00
# 4997     Agência de Fomento do Estado da Bahia S/A  Real     65000.00
# 4998                           Banco do Brasil S/A  Real   1250000.00
# 4999                       Caixa Econômica Federal  Real  10585540.36
#
#       pvl_assoc_divida  pvl_contradado_credor data_status
# 0                    0                      1  05/06/2023
# 1                    0                      1  10/09/2021
# 2                    0                      0  30/07/2021
# 3                    0                      0  03/01/2022
# 4                    0                      1  13/09/2021
# ...                ...                    ...         ...
# 4995                 1                      0  22/04/2014
# 4996                 1                      0  16/05/2012
# 4997                 0                      0  19/05/2011
# 4998                 0                      0  16/08/2010
# 4999                 1                      0  17/04/2014
#
# [5000 rows x 18 columns]

# %%
sao_paulo = df['uf']== 'SP' # separando apenas o estado do São Paulo

# %%
df.columns #vizualisando quais são as colunas existentes na base de dados
# Out:
# Index(['id_pleito', 'tipo_interessado', 'interessado', 'cod_ibge', 'uf',
#        'num_pvl', 'status', 'num_processo', 'data_protocolo', 'tipo_operacao',
#        'finalidade', 'tipo_credor', 'credor', 'moeda', 'valor',
#        'pvl_assoc_divida', 'pvl_contradado_credor', 'data_status'],
#       dtype='object')

# %%
# 2) Seu código aqui
df['status'].value_counts().head(3) #utilizando esta função conseguimos ver quais são os 3 status mais frequentes em nossa base
# Out:
# status
# Deferido             2862
# Deferido (PVL-IF)     783
# Arquivado             498
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
df.info() #verificando o tipo das informações salvas na base de dados
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              5000 non-null   int64
#  1   tipo_interessado       5000 non-null   object
#  2   interessado            5000 non-null   object
#  3   cod_ibge               5000 non-null   int64
#  4   uf                     5000 non-null   object
#  5   num_pvl                1677 non-null   object
#  6   status                 5000 non-null   object
#  7   num_processo           4188 non-null   object
#  8   data_protocolo         4188 non-null   object
#  9   tipo_operacao          5000 non-null   object
#  10  finalidade             5000 non-null   object
#  11  tipo_credor            5000 non-null   object
#  12  credor                 5000 non-null   object
#  13  moeda                  5000 non-null   object
#  14  valor                  5000 non-null   float64
#  15  pvl_assoc_divida       5000 non-null   int64
#  16  pvl_contradado_credor  5000 non-null   int64
#  17  data_status            5000 non-null   object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 703.3+ KB

# %%
df['data_status'].head() # verificando o formado das datas
# Out:
# 0    05/06/2023
# 1    10/09/2021
# 2    30/07/2021
# 3    03/01/2022
# 4    13/09/2021
# Name: data_status, dtype: object

# %%
df['ano'] = df['data_status'].str.extract('(\d{4})') #extraindo o ano da data

# %%
df['ano'].head() # mostrando os anos
# Out:
# 0    2023
# 1    2021
# 2    2021
# 3    2022
# 4    2021
# Name: ano, dtype: object

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consulta_dados(uf, tipo_interessado):
    # Filtra os dados com base no UF e tipo de interessado
    dados_filtrados = df[(df['uf'] == uf) & (df['tipo_interessado'] == tipo_interessado)]
    return dados_filtrados

# %%
# testando a função
uf_consulta = 'SP'
tipo_interessado_consulta = 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta
# Out:
#       id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 104       48051           Estado   São Paulo        35  SP
# 314       30127           Estado   São Paulo        35  SP
# 657       11458           Estado   São Paulo        35  SP
# 865        7118           Estado   São Paulo        35  SP
# 885        6536           Estado   São Paulo        35  SP
# 896        7053           Estado   São Paulo        35  SP
# 1757      28104           Estado   São Paulo        35  SP
# 2161      11263           Estado   São Paulo        35  SP
# 2208      11522           Estado   São Paulo        35  SP
# 2420       5688           Estado   São Paulo        35  SP
# 2535       6774           Estado   São Paulo        35  SP
# 2540       6342           Estado   São Paulo        35  SP
# 2582      10223           Estado   São Paulo        35  SP
# 2611      10377           Estado   São Paulo        35  SP
# 2629       8619           Estado   São Paulo        35  SP
# 2667       9030           Estado   São Paulo        35  SP
# 3084       5006           Estado   São Paulo        35  SP
# 3206       5623           Estado   São Paulo        35  SP
# 3546      11755           Estado   São Paulo        35  SP
# 3694      26940           Estado   São Paulo        35  SP
# 3823      28058           Estado   São Paulo        35  SP
# 3905      11505           Estado   São Paulo        35  SP
# 4025      10456           Estado   São Paulo        35  SP
# 4506      13181           Estado   São Paulo        35  SP
# 4681      60069           Estado   São Paulo        35  SP
# 3206  Operação contratual externa (com garantia da U...
# 3546  Operação contratual externa (com garantia da U...
# 3694                        Operação contratual interna
# 3823  Operação contratual interna (com garantia da U...
# 3905  Operação contratual externa (com garantia da U...
# 4025  Operação contratual externa (com garantia da U...
# 4506                        Operação contratual interna
# 4681                              Concessão de garantia
# 4962  Operação contratual interna (com garantia da U...
#
#                                              finalidade  \
# 104                                      Infraestrutura
# 314                                            Profisco
# 657                                      Infraestrutura
# 865                                      Infraestrutura
# 885                                      Infraestrutura
# 896                                      Infraestrutura
# 1757                                     Infraestrutura
# 2161                                     Infraestrutura
# 2208                                     Infraestrutura
# 2420  Concessão de garantia a empresa estatal não de...
# 2535                                     Infraestrutura
# 2540                                     Infraestrutura
# 2582  Concessão de garantia a empresa estatal não de...
# 2611  Aquisição de terrenos, imóveis e/ou construção...
# 2629                                     Infraestrutura
# 2667                  PAC 2 - Mobilidade Médias Cidades
# 3084  Concessão de garantia a empresa estatal não de...
# 3206                                     Infraestrutura
# 3546                                           Profisco
# 3694                            Renegociação de dívidas
# 3823                                     Infraestrutura
# 3905                                     Infraestrutura
# 4025                                     Infraestrutura
# 4506                                     Infraestrutura
# 4681  Concessão de garantia a empresa estatal não de...
# 4962                                     Infraestrutura
#
#                                tipo_credor  \
# 104   Instituição Financeira Internacional
# 314   Instituição Financeira Internacional
# 657   Instituição Financeira Internacional
# 865   Instituição Financeira Internacional
# 885        Instituição Financeira Nacional
# 896   Instituição Financeira Internacional
# 1757       Instituição Financeira Nacional
# 2161  Instituição Financeira Internacional
# 2208  Instituição Financeira Internacional
# 2420       Instituição Financeira Nacional
# 2535       Instituição Financeira Nacional
# 2540       Instituição Financeira Nacional
# 2582  Instituição Financeira Internacional
# 2611  Instituição Financeira Internacional
# 2629  Instituição Financeira Internacional
# 2667       Instituição Financeira Nacional
# 3084  Instituição Financeira Internacional
# 3206  Instituição Financeira Internacional
# 3546  Instituição Financeira Internacional
# 3694                                 União
# 3823       Instituição Financeira Nacional
# 3905  Instituição Financeira Internacional
# 4025  Instituição Financeira Internacional
# 4506       Instituição Financeira Nacional
# 4681  Instituição Financeira Internacional
# 4962       Instituição Financeira Nacional
#
#                                                  credor          moeda  \
# 104                        Corporação Andina de Fomento  Dólar dos EUA
# 314             Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 657   Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 865                        Corporação Andina de Fomento  Dólar dos EUA
# 885   Banco Nacional de Desenvolvimento Econômico e ...           Real
# 896                 Agência Francesa de Desenvolvimento           Euro
# 1757                            Caixa Econômica Federal           Real
# 2161            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 2208  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 2420  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 2535  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 2540  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 2582             Japan International Cooperation Agency           Iene
# 2611                Sumitomo Mitsui Banking Corporation  Dólar dos EUA
# 2629  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 2667                            Caixa Econômica Federal           Real
# 3084             Japan International Cooperation Agency           Iene
# 3206  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 3546            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 3694                                              União           Real
# 3823                      Banco Santander (Brasil) S.A.           Real
# 3905            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 4025  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 4506  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4681                               New Development Bank  Dólar dos EUA
# 4962  Banco Nacional de Desenvolvimento Econômico e ...           Real
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status   ano
# 104   5.500000e+08                 0                      0  31/05/2022  2022
# 314   8.712000e+07                 1                      0  10/07/2019  2019
# 657   6.504120e+08                 1                      0  25/11/2009  2009
# 865   2.040000e+08                 1                      0  27/02/2014  2014
# 885   9.220000e+08                 1                      0  19/04/2012  2012
# 896   3.000000e+08                 1                      0  05/03/2014  2014
# 1757  9.000000e+08                 0                      0  05/02/2019  2019
# 2161  7.486330e+08                 0                      0  10/10/2011  2011
# 1698                            Renegociação de dívidas
# 1852  Concessão de garantia a empresa estatal não de...
# 2409                                     Infraestrutura
# 3796                                     Infraestrutura
# 3954                                     Multissetorial
# 4275                                     Infraestrutura
# 4323                                     Multissetorial
# 4383                              Desenvolvimento rural
#
#                                tipo_credor  \
# 142        Instituição Financeira Nacional
# 409        Instituição Financeira Nacional
# 879   Instituição Financeira Internacional
# 1698                                 União
# 1852  Instituição Financeira Internacional
# 2409       Instituição Financeira Nacional
# 3796  Instituição Financeira Internacional
# 3954  Instituição Financeira Internacional
# 4275  Instituição Financeira Internacional
# 4323  Instituição Financeira Internacional
# 4383  Instituição Financeira Internacional
#
#                                                  credor          moeda  \
# 142   Banco Nacional de Desenvolvimento Econômico e ...           Real
# 409   Banco Nacional de Desenvolvimento Econômico e ...           Real
# 879   Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 1698                                              União           Real
# 1852                     Kreditanstalt für Wiederaufbau           Euro
# 2409                                Banco do Brasil S/A           Real
# 3796            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 3954  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 4275  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 4323            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 4383  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status   ano
# 142   3.488900e+07                 1                      0  25/06/2010  2010
# 409   1.326390e+09                 1                      0  02/01/2013  2013
# 879   9.760000e+08                 1                      0  02/07/2008  2008
# 1698  9.396517e+10                 0                      0  04/05/2021  2021
# 1852  1.000000e+08                 0                      0  19/05/2011  2011
# 2409  1.500000e+09                 1                      0  12/08/2013  2013
# 3796  5.000000e+07                 1                      0  01/04/2010  2010
# 3954  1.700000e+08                 1                      0  19/04/2006  2006
# 4275  3.500000e+07                 0                      0  20/02/2004  2004
# 4323  5.000000e+07                 0                      0  29/04/2016  2016
# 4383  3.500000e+07                 1                      0  09/12/2004  2004

# %%
resultado_consulta['status'].value_counts() # verificando os tipos de status presentes na base de dados e sua frequencia
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    6
# Deferido                                                 2
# Arquivado pela STN                                       1
# Arquivado                                                1
# Arquivado a pedido                                       1
# Name: count, dtype: int64

# %%
status_MG = resultado_consulta['status'] == 'Arquivado por decurso de prazo'
status_MG.value_counts() # realizando a contagem dos valores filtrados
# Out:
# status
# False    11
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
uf_consulta = 'BA'
tipo_interessado_consulta = 'Município'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)

# %%
resultado_consulta['status'].value_counts()
# Out:
# status
# Deferido                                                 108
# Arquivado por decurso de prazo                            33
# Deferido (PVL-IF)                                         24
# Arquivado                                                 19
# Regularizado                                              13
# Encaminhado à PGFN com manifestação técnica favorável      6
# Pendente de regularização                                  3
# Arquivado a pedido                                         3
# Em retificação pelo credor                                 1
# Em retificação pelo credor (PVL-IF)                        1
# Em retificação pelo interessado                            1
# Indeferido                                                 1
# Name: count, dtype: int64

# %%
deferido_data = resultado_consulta[resultado_consulta['status'] == 'Deferido'] #Filtrando apenas os deferidos

# %%
deferido_data
# Out:
#       id_pleito tipo_interessado          interessado  cod_ibge  uf  \
# 43        67131        Município     Lauro de Freitas   2919207  BA
# 101       65395        Município  Teixeira de Freitas   2931350  BA
# 133        7981        Município            Jiquiriçá   2918209  BA
# 143       61562        Município         Simões Filho   2930709  BA
# 190       63253        Município    Itaguaçu da Bahia   2915353  BA
# ...         ...              ...                  ...       ...  ..
# 4895       9078        Município              Ituberá   2917300  BA
# 4900       9177        Município              Caetité   2905206  BA
# 4973      64400        Município      Morro do Chapéu   2921708  BA
# 4981       7404        Município              Lençóis   2919306  BA
# 4997       6905        Município             Ipecaetá   2913804  BA
#
#                    num_pvl    status          num_processo  \
# 43    PVL02.003848/2023-75  Deferido  17944.105270/2023-53
# 101   PVL02.002281/2023-10  Deferido  17944.102708/2023-41
# 133                   None  Deferido  17944.000689/2010-03
# 143   PVL02.005914/2022-61  Deferido  17944.103664/2022-96
# 190   PVL02.000031/2023-45  Deferido  17944.100370/2023-93
# ...                    ...       ...                   ...
# 4895                  None  Deferido  17944.000898/2012-19
# 4900                  None  Deferido  17944.000919/2013-79
# 4973  PVL02.000824/2023-64  Deferido  17944.101984/2023-92
# 4981                  None  Deferido  17944.000567/2010-17
# 4997                  None  Deferido  17944.000456/2011-83
#
#             data_protocolo                tipo_operacao  \
# 43    2023-11-13T15:20:47Z  Operação contratual interna
# 101   2023-06-26T13:11:22Z  Operação contratual interna
# 133   2010-05-24T03:00:00Z  Operação contratual interna
# 143   2022-11-01T15:58:20Z  Operação contratual interna
# 190   2023-03-16T14:49:27Z  Operação contratual interna
# ...                    ...                          ...
# 4895  2012-08-22T03:00:00Z  Operação contratual interna
# 4900  2013-09-02T03:00:00Z  Operação contratual interna
# 4973  2023-05-11T20:01:23Z  Operação contratual interna
# 4981  2010-05-12T03:00:00Z  Operação contratual interna
# 4997  2011-05-03T03:00:00Z  Operação contratual interna
#
#                                           finalidade  \
# 43                                    Infraestrutura
# 101                                   Infraestrutura
# 133   Aquisição de máquinas, equipamentos e veículos
# 143                                   Infraestrutura
# 190                                   Infraestrutura
# ...                                              ...
# 4895                                            PMAT
# 4900  Aquisição de máquinas, equipamentos e veículos
# 4973                                  Infraestrutura
# 4981  Aquisição de máquinas, equipamentos e veículos
# 4997  Aquisição de máquinas, equipamentos e veículos
#
#                           tipo_credor  \
# 43    Instituição Financeira Nacional
# 101   Instituição Financeira Nacional
# 133   Instituição Financeira Nacional
# 143   Instituição Financeira Nacional
# 190   Instituição Financeira Nacional
# ...                               ...
# 4895  Instituição Financeira Nacional
# 4900  Instituição Financeira Nacional
# 4973  Instituição Financeira Nacional
# 4981  Instituição Financeira Nacional
# 4997  Instituição Financeira Nacional
#
#                                          credor moeda       valor  \
# 43                          Banco do Brasil S/A  Real  25000000.0
# 101                     Caixa Econômica Federal  Real  60000000.0
# 133   Agência de Fomento do Estado da Bahia S/A  Real    500000.0
# 143                         Banco do Brasil S/A  Real  11500000.0
# 190                     Caixa Econômica Federal  Real  10000000.0
# ...                                         ...   ...         ...
# 4895  Agência de Fomento do Estado da Bahia S/A  Real   3900000.0
# 4900  Agência de Fomento do Estado da Bahia S/A  Real   1800000.0
# 4973                    Caixa Econômica Federal  Real   8000000.0
# 4981  Agência de Fomento do Estado da Bahia S/A  Real     65000.0
# 4997  Agência de Fomento do Estado da Bahia S/A  Real     65000.0
#
#       pvl_assoc_divida  pvl_contradado_credor data_status   ano
# 43                   0                      1  17/11/2023  2023
# 101                  0                      0  28/06/2023  2023
# 133                  0                      0  17/06/2010  2010
# 143                  0                      1  04/11/2022  2022
# 190                  0                      1  17/03/2023  2023
# ...                ...                    ...         ...   ...
# 4895                 0                      0  10/09/2012  2012
# 4900                 1                      0  09/10/2013  2013
# 4973                 0                      0  17/05/2023  2023
# 4981                 0                      0  08/06/2010  2010
# 4997                 0                      0  19/05/2011  2011
#
# [108 rows x 19 columns]

# %%
contagem_deferido_por_municipio = deferido_data['interessado'].value_counts() #contando a frequencia dos municipios que aparecem
contagem_deferido_por_municipio.head()
# Out:
# interessado
# Lauro de Freitas        3
# Riachão do Jacuípe      3
# Teixeira de Freitas     3
# Vitória da Conquista    3
# Bom Jesus da Lapa       2
# Name: count, dtype: int64

# %%
# 4) Seu código aqui
uf_consulta = 'BA'
tipo_interessado_consulta = 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta.to_csv('Solicitações_Bahia.csv')
